# %%
from cplane_np_hw import JuliaPlane

# %%
# use np.vectorize()
p1=JuliaPlane(-2,2,3000,-2,2,3000)
#c=0
# %time p1.show(0)
# Out:
# /projects/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# CPU times: user 6min 5s, sys: 1.45 s, total: 6min 7s
# Wall time: 6min 13s

# %%
# use @nb.vectorize([nb.int32(nb.complex128)])
p1=JuliaPlane(-2,2,3000,-2,2,3000)
#c=0
# %time p1.show(0)
# Out:
# /projects/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# CPU times: user 2.54 s, sys: 760 ms, total: 3.3 s
# Wall time: 3.5 s

# %% [markdown]
# **How much faster does the code run after adding this one line of code?**
#
#    It abouts 111 times faster.
#
#
#
# |      | np.vectorize   |   numba.vectorize |
# |------|----------------|-------------------|
# | Time |    6min 7s     |   3.3 s           |
